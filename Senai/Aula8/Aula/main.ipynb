# %% [markdown]
# # PACOTES PARA INSTALAR:

# %% [markdown]
# npm init -> para começar o projeto
#
# npm i
#
# npm i typescript @types/node tsx -D -> configurar o TS
#
# npx tsc --init -> cria o typescript
#
# npm i express @types/express -> instalar o express
#
# npm i mongoose config -> extensão do mongo
#
# npm i --save-dev @types/config

# %% [markdown]
# AAAAAAAAAA
